# %% [markdown]
# # Planar Wrist Angle Example

# %%
import matplotlib.pyplot as plt
import numpy as np
from numpy import sin, cos, tan, pi

import robotics
from robotics import Rz, Ry, Rz, sind, cosd, DH, HTz, HTinv
rtd = 180/pi
dtr = pi/180

# %% [markdown]
# ## Three Link Planar Robot
#
# <img src="https://faculty.gvsu.edu/kraussry/445_images/learning_activities/inverse_kin_sketches/inv_kin_3_3DOF_planar.png" width=400px>

# %% [markdown]
# ### Problem Statement

# %% [markdown]
# Find $\theta_3$ using the wrist angles approach discusseed in lecture, namely:
#
# $$^W_{tip}\mathbf{T}_{\textrm{numeric}} \; = \; ^W_{tip}\mathbf{T}_{\textrm{symbolic}}$$
#
# Use the link lengths below along with the given $^0_{tip}\mathbf{T}$ matrix
#
# - assume that $\theta_1$ and $\theta_2$ were found using the wrist position and the geometric approach on the side view
#
# Verify your final answer using forward kinematics.

# %%
L1 = 7
L2 = 6
L3 = 3

# %%
T_0tip = np.array([[ 0.40673664, -0.91354546,  0.        , 13.12362362],
       [ 0.91354546,  0.40673664,  0.        ,  7.34413355],
       [ 0.        ,  0.        ,  1.        ,  0.        ],
       [ 0.        ,  0.        ,  0.        ,  1.        ]])
T_0tip
# Out:
# array([[ 0.40673664, -0.91354546,  0.        , 13.12362362],
#        [ 0.91354546,  0.40673664,  0.        ,  7.34413355],
#        [ 0.        ,  0.        ,  1.        ,  0.        ],
#        [ 0.        ,  0.        ,  0.        ,  1.        ]])

# %%
th1 = 11
th2 = 22

# %% [markdown]
# ## Symbolic Forward Kinematics to find $^W_{tip}\mathbf{T}_{\textrm{symbolic}}$

# %%
import sympy
import robotics_sympy

# %%
th3s, L3s = sympy.symbols(["\\theta_3", "L_3"])
