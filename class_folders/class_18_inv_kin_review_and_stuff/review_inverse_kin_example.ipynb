# %% [markdown]
# ## Inverse Kinematics Review Example

# %%
import matplotlib.pyplot as plt
import numpy as np
from numpy import sin, cos, tan, pi
import robotics
import math
from robotics import Rx, Ry, Rz, sind, cosd, DH, HTinv, prettymat
rtd = 180/pi
dtr = pi/180

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# The robot shown below has a weird offset in its final link.  Solve the inverse kinematics problem to find values for $\theta_1$, $\theta_2$, anv $\theta_3$ so that the tip position and orientation match $^0_{tip}\mathbf{T}$ given below.
#
# **Note:** $C$ is along $\hat{X}_3$

# %% [markdown]
# <img src="https://faculty.gvsu.edu/kraussry/445_images/inverse_kin_sketches/inv_kin_review_example.jpg" width=600px>

# %%
A = 9
B = 7
C = 5
D = 8

# %%
T0tip = np.array([[ 0.18917455, -0.98129266,  0.0357449 ,  2.17473589],
       [ 0.96423073,  0.19252197,  0.18219329, 11.08472147],
       [-0.18566662,  0.        ,  0.9826128 , 20.93387805],
       [ 0.        ,  0.        ,  0.        ,  1.        ]])

# %%
T0tip
# Out:
# array([[ 0.18917455, -0.98129266,  0.0357449 ,  2.17473589],
#        [ 0.96423073,  0.19252197,  0.18219329, 11.08472147],
#        [-0.18566662,  0.        ,  0.9826128 , 20.93387805],
#        [ 0.        ,  0.        ,  0.        ,  1.        ]])
