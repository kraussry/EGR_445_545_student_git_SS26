# %% [markdown]
# ## Review: The $^A_B\mathbf{R}$ Convention(s) (Slide 2)

# %% [markdown]
# \columnsbegin
#
# \column{0.5\textwidth}
#
# consider a single-link robot:
#
# - what frame do we want to map to?
# - what frame do we want to map from?
# - what frame moves?
#
#
# \column{0.5\textwidth}
#
# <img src="../../445_images/latex_robot_schematics/single_link_robot.png" width=600px>
# :fh: 0.5
#
#
# \columnsend

# %% [markdown]
# ## Review: what does this mean? (Slide 3)

# %% [markdown]
# $$^A_B \mathbf{R} \; = \; \left[ \begin{matrix} ^A\hat{X}_B & ^A\hat{Y}_B & ^A\hat{Z}_B \end{matrix} \right]$$

# %% [markdown]
# ## Review: draw the axes (Slide 4)

# %% [markdown]
# $$^A_B\mathbf{R} = \; \begin{bmatrix} 0.8 & 0.6 & 0 \\ -0.6 & 0.8 & 0 \\ 0 & 0 & 1 \end{bmatrix}$$
#
# - how do I check the signs on my sketch?

# %% [markdown]
# ## Review: draw the axes 2 (Slide 5)

# %% [markdown]
# $$^A_B\mathbf{R} = \; \begin{bmatrix} 0.8 & 0 & 0.6 \\ 0.6 & 0 & -0.8 \\ 0 & 1 & 0 \end{bmatrix}$$

# %% [markdown]
# ## Review: Inverse of an HT Matrix (Slide 6)

# %% [markdown]
# what does this mean?:
#
# $$^B_A\mathbf{T} = \; \left[ \begin{matrix} & ^A_B\mathbf{R}^T & & -^A_B\mathbf{R}^T \cdot \, ^A\mathbf{P}_{BORG} \\ 0 & 0 & 0 & 1 \end{matrix}\right] \; \textrm{ (eqn. 2.45)}$$
