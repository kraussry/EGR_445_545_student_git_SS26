# %% [markdown]
# ## Inverse Kinematics Simple Example

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
from numpy import sin, cos, tan, pi
import robotics
from robotics import Rz, Ry, Rz, sind, cosd, DH
rtd = 180/pi
dtr = pi/180

# %% [markdown]
# <img src="https://faculty.gvsu.edu/kraussry/445_images/inverse_kin_sketches/Simple_2_DOF_3_D_Robot_cropped.jpg" width=300px>

# %% [markdown]
# ## Problem Statement
#
# Given the lengths

# %%
A = 10
B = 7

# %% [markdown]
# find $\theta_1$ and $\theta_2$ to place the tip of the robot at
# $$^0P_{tip} = \begin{bmatrix} 6.478 \\ 1.142 \\ 12.39\end{bmatrix}$$

# %% [markdown]
# - verify your solution with forward kinematics

# %% [markdown]
# ## Guiding Questions
#
# - what can I learn from a top view?
# - what can I learn from a sideview?
#
#
# ## Nagging Question
#
# - is this problem solvable?
#     - it seems like I have 2 joints but 3 DOF
