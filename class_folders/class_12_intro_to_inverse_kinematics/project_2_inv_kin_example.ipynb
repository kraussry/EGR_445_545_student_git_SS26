# %%
import matplotlib.pyplot as plt
import numpy as np
from numpy import sin, cos, tan, pi
import robotics
from robotics import Rx, Ry, Rz, sind, cosd, DH, prettymat
rtd = 180/pi
dtr = pi/180

# %% [markdown]
# <img src="https://faculty.gvsu.edu/kraussry/445_images/lecture_slides_images_445/class_12_inv_kin/class_12_intro_to_inverse_kinematics_main_markedup_0014.jpg" width=800px>

# %% [markdown]
# <img src="https://faculty.gvsu.edu/kraussry/445_images/lecture_slides_images_445/class_12_inv_kin/class_12_intro_to_inverse_kinematics_main_markedup_0015.jpg" width=800px>

# %%
P_tip_0 = np.array([12,6,5])

# %%
H = 7
A = 10
B = 8

# %% [markdown]
# ## Solve for $\theta_1$ from top view

# %% [markdown]
# <img src="https://faculty.gvsu.edu/kraussry/445_images/lecture_slides_images_445/class_12_inv_kin/class_12_intro_to_inverse_kinematics_main_markedup_0016.jpg" width=800px>

# %%
th1 = np.arctan2(P_tip_0[1], P_tip_0[0])*rtd`
th1
# Out:
# np.float64(26.56505117707799)

# %% [markdown]
# ## Find $^1P_{tip}$ for a side view analysis

# %% [markdown]
# <img src="https://faculty.gvsu.edu/kraussry/445_images/lecture_slides_images_445/class_12_inv_kin/class_12_intro_to_inverse_kinematics_main_markedup_0017.jpg" width=800px>

# %%
T01 = DH(0,0,th1,H)

# %%
T10 = robotics.HTinv(T01)

# %%
P_tip_0 = robotics.append_one(P_tip_0)

# %%
P_tip_1 = prettymat(T10 @ P_tip_0)
P_tip_1
# Out:
# array([13.41640786,  0.        , -2.        ,  1.        ])
